# %%
#Importing the library
import pandas as pd
import numpy as np
import requests
import selenium
from selenium import webdriver
from bs4 import BeautifulSoup
#importing the Web driver
dr=webdriver.Chrome(r"G:\Fliprobo data\WEB SCAPING FLIP ROBO\chromedriver_win32\chromedriver.exe")
import time

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import re

# %%
url1="https://timesofindia.indiatimes.com/2020/12/1/archivelist/year-2020,month-12,starttime-44166.cms"

# %%
dr.get(url1)

# %%
# all available urls in 1/12/2020
urls = dr.find_elements_by_xpath('//span[@style="font-family:arial ;font-size:12;color: #006699"]/a')
urls
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9c4b8cb30b02744ece8cc596daded63c", element="14ee95df-84b2-454b-93ea-e6c78adc4c42")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c4b8cb30b02744ece8cc596daded63c", element="ce539707-5326-4b09-9c62-1202fded64c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c4b8cb30b02744ece8cc596daded63c", element="9ff89746-8406-435f-b73a-41051920265b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c4b8cb30b02744ece8cc596daded63c", element="fbc403cf-e67e-498d-bc7e-9c2b198c5928")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c4b8cb30b02744ece8cc596daded63c", element="938103df-a54f-4e03-b613-d1e62fa62754")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9c4b8cb30b02744ece8cc596daded63c", element="65bf2c24-267f-4670-aae8-833c2ea102a1")>,
# ...

# %%
# Now again apply for loop for extracted data from each link.
